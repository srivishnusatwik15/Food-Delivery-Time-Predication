# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/home/srivishnu/Documents/cdc documents/food delivery project/food_delivery.csv", encoding='latin1')

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 45588  7C09      JAPRES04DEL01                   30                      4.8
# 45589  D641      AGRRES16DEL01                   21                      4.6
# 45590  4F8D     CHENRES08DEL03                   30                      4.9
# 45591  5EEE    COIMBRES11DEL01                   20                      4.7
# 45592  5FB2   RANCHIRES09DEL02                   23                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude Type_of_order Type_of_vehicle  \
# 0                        75.912471        Snack      motorcycle
# 1                        77.813237        Snack         scooter
# 2                        77.688400       Drinks      motorcycle
# 3                        77.026494       Buffet      motorcycle
# 4                        80.289982        Snack         scooter
# ...                            ...           ...             ...
# 45588                    75.804257         Meal      motorcycle
# 45589                     0.070000       Buffet      motorcycle
# 45590                    80.272439       Drinks         scooter
# 45591                    77.026241        Snack      motorcycle
# 45592                    85.405731        Snack         scooter
#
#        Time_taken(min)
# 0                   24
# 1                   33
# 2                   26
# 3                   21
# 4                   30
# ...                ...
# 45588               32
# 45589               36
# 45590               16
# 45591               26
# 45592               36
#
# [45593 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Type_of_order', 'Type_of_vehicle',
#        'Time_taken(min)'],
#       dtype='object')

# %%
df.shape
# Out:
# (45593, 11)

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         45593.000000             45593.000000         45593.000000
# mean             29.544075                 4.632367            17.017729
# std               5.696793                 0.327708             8.185109
# min              15.000000                 1.000000           -30.905562
# 25%              25.000000                 4.600000            12.933284
# 50%              29.000000                 4.700000            18.546947
# 75%              34.000000                 4.800000            22.728163
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          45593.000000                45593.000000
# mean              70.231332                   17.465186
# std               22.883647                    7.335122
# min              -88.366217                    0.010000
# 25%               73.170000                   12.988453
# 50%               75.898497                   18.633934
# 75%               78.044095                   22.785049
# max               88.433452                   31.054057
#
#        Delivery_location_longitude  Time_taken(min)
# count                 45593.000000     45593.000000
# mean                     70.845702        26.294607
# std                      21.118812         9.383806
# min                       0.010000        10.000000
# 25%                      73.280000        19.000000
# 50%                      76.002574        26.000000
# 75%                      78.107044        32.000000
# max                      88.563452        54.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  int64
#  3   Delivery_person_Ratings      45593 non-null  float64
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Type_of_order                45593 non-null  object
#  9   Type_of_vehicle              45593 non-null  object
#  10  Time_taken(min)              45593 non-null  int64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 3.8+ MB

# %%
df.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Type_of_order                  0
# Type_of_vehicle                0
# Time_taken(min)                0
# dtype: int64

# %%
df.nunique()
# Out:
# ID                             45451
# Delivery_person_ID              1320
# Delivery_person_Age               22
# Delivery_person_Ratings           28
# Restaurant_latitude              657
# Restaurant_longitude             518
# Delivery_location_latitude      4373
# Delivery_location_longitude     4373
# Type_of_order                      4
# Type_of_vehicle                    4
# Time_taken(min)                   45
# dtype: int64

# %%
object_columns = df.select_dtypes(include='object').columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
print("Object Columns:")
print(object_columns)
print("Numerical Columns:")
print(numerical_columns)
# Out:
# Object Columns:
# Index(['ID', 'Delivery_person_ID', 'Type_of_order', 'Type_of_vehicle'], dtype='object')
# Numerical Columns:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Time_taken(min)'],
#       dtype='object')

# %%
df["Type_of_order"].unique()
# Out:
# array(['Snack ', 'Drinks ', 'Buffet ', 'Meal '], dtype=object)

# %%
df["Type_of_order"].value_counts()
# Out:
# Snack      11533
# Meal       11458
# Drinks     11322
# Buffet     11280
# Name: Type_of_order, dtype: int64

# %%
sns.countplot(x="Type_of_order",data=df)
plt.title("Type_of_order count")
plt.show()

# %%
counts = df['Type_of_order'].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.1f%%', colors=sns.color_palette('hls'))
plt.title('Type_of_order')
# Out:
# Text(0.5, 1.0, 'Type_of_order')

# %%
df["Type_of_vehicle"].unique()
# Out:
# array(['motorcycle ', 'scooter ', 'electric_scooter ', 'bicycle '],
#       dtype=object)

# %%
df["Type_of_vehicle"].value_counts()
# Out:
# motorcycle           26435
# scooter              15276
# electric_scooter      3814
# bicycle                 68
# Name: Type_of_vehicle, dtype: int64

# %%
sns.countplot(x="Type_of_vehicle", data = df)
plt.title("Type_of_vehicle count")
plt.show()

# %%
counts = df["Type_of_vehicle"].value_counts()
plt.pie(counts, labels=counts.index, autopct='%0.1f%%', colors=sns.color_palette('hls'))
plt.title("Type_of_vehicle")
plt.show()

# %%
for i in numerical_columns:
    sns.histplot(df[i], kde = True, bins = 20, palette = "hls")
    #plt.xticks(rotation = 90)
    plt.show()
# Out:
# /tmp/ipykernel_20182/1530634265.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, bins = 20, palette = "hls")
# /tmp/ipykernel_20182/1530634265.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, bins = 20, palette = "hls")
# /tmp/ipykernel_20182/1530634265.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, bins = 20, palette = "hls")
# /tmp/ipykernel_20182/1530634265.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, bins = 20, palette = "hls")
# /tmp/ipykernel_20182/1530634265.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, bins = 20, palette = "hls")
# /tmp/ipykernel_20182/1530634265.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, bins = 20, palette = "hls")
# /tmp/ipykernel_20182/1530634265.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[i], kde = True, bins = 20, palette = "hls")

# %%
for i in numerical_columns:
    sns.boxplot(df[i], palette = "hls")
    plt.show()

# %%
for i in numerical_columns:
    sns.violinplot(df[i], palette = "hls")
    plt.show()

# %%
for i in numerical_columns:
    sns.boxplot(x = df["Type_of_order"], y = df[i], data = df, palette = "hls")
    plt.show()

# %%
for i in numerical_columns:
    sns.violinplot(x = df["Type_of_order"], y = df[i], data = df, palette = "hls")
    plt.show()

# %%
df.corr()
# Out:
# /tmp/ipykernel_20182/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                              Delivery_person_Age  Delivery_person_Ratings  \
# Delivery_person_Age                     1.000000                -0.067449
# Delivery_person_Ratings                -0.067449                 1.000000
# Restaurant_latitude                    -0.001955                -0.004846
# Restaurant_longitude                   -0.006796                -0.011147
# Delivery_location_latitude              0.002359                -0.010198
# Delivery_location_longitude            -0.000593                -0.013350
# Time_taken(min)                         0.292708                -0.331103
#
#                              Restaurant_latitude  Restaurant_longitude  \
# Delivery_person_Age                    -0.001955             -0.006796
# Delivery_person_Ratings                -0.004846             -0.011147
# Restaurant_latitude                     1.000000              0.661784
# Restaurant_longitude                    0.661784              1.000000
# Delivery_location_latitude              0.866378              0.632293
# Delivery_location_longitude             0.602713              0.915026
# Time_taken(min)                         0.013981              0.007821
#
#                              Delivery_location_latitude  \
# Delivery_person_Age                            0.002359
# Delivery_person_Ratings                       -0.010198
# Restaurant_latitude                            0.866378
# Restaurant_longitude                           0.632293
# Delivery_location_latitude                     1.000000
# Delivery_location_longitude                    0.690515
# Time_taken(min)                                0.014243
#
#                              Delivery_location_longitude  Time_taken(min)
# Delivery_person_Age                            -0.000593         0.292708
# Delivery_person_Ratings                        -0.013350        -0.331103
# Restaurant_latitude                             0.602713         0.013981
# Restaurant_longitude                            0.915026         0.007821
# Delivery_location_latitude                      0.690515         0.014243
# Delivery_location_longitude                     1.000000         0.007625
# Time_taken(min)                                 0.007625         1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap="Greens")
# Out:
# /tmp/ipykernel_20182/1199863406.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap="Greens")
# <Axes: >

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 45588  7C09      JAPRES04DEL01                   30                      4.8
# 45589  D641      AGRRES16DEL01                   21                      4.6
# 45590  4F8D     CHENRES08DEL03                   30                      4.9
# 45591  5EEE    COIMBRES11DEL01                   20                      4.7
# 45592  5FB2   RANCHIRES09DEL02                   23                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude Type_of_order Type_of_vehicle  \
# 0                        75.912471        Snack      motorcycle
# 1                        77.813237        Snack         scooter
# 2                        77.688400       Drinks      motorcycle
# 3                        77.026494       Buffet      motorcycle
# 4                        80.289982        Snack         scooter
# ...                            ...           ...             ...
# 45588                    75.804257         Meal      motorcycle
# 45589                     0.070000       Buffet      motorcycle
# 45590                    80.272439       Drinks         scooter
# 45591                    77.026241        Snack      motorcycle
# 45592                    85.405731        Snack         scooter
#
#        Time_taken(min)
# 0                   24
# 1                   33
# 2                   26
# 3                   21
# 4                   30
# ...                ...
# 45588               32
# 45589               36
# 45590               16
# 45591               26
# 45592               36
#
# [45593 rows x 11 columns]

# %%
df['hour_of_day'] = pd.to_datetime(df['Time_taken(min)'], unit='m').dt.hour
df['day_of_week'] = pd.to_datetime(df['Time_taken(min)'], unit='m').dt.dayofweek
df['month_of_year'] = pd.to_datetime(df['Time_taken(min)'], unit='m').dt.month

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 45588  7C09      JAPRES04DEL01                   30                      4.8
# 45589  D641      AGRRES16DEL01                   21                      4.6
# 45590  4F8D     CHENRES08DEL03                   30                      4.9
# 45591  5EEE    COIMBRES11DEL01                   20                      4.7
# 45592  5FB2   RANCHIRES09DEL02                   23                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude Type_of_order Type_of_vehicle  \
# 0                        75.912471        Snack      motorcycle
# 1                        77.813237        Snack         scooter
# 2                        77.688400       Drinks      motorcycle
# 3                        77.026494       Buffet      motorcycle
# 4                        80.289982        Snack         scooter
# ...                            ...           ...             ...
# 45588                    75.804257         Meal      motorcycle
# 45589                     0.070000       Buffet      motorcycle
# 45590                    80.272439       Drinks         scooter
# 45591                    77.026241        Snack      motorcycle
# 45592                    85.405731        Snack         scooter
#
#        Time_taken(min)  hour_of_day  day_of_week  month_of_year
# 0                   24            0            3              1
# 1                   33            0            3              1
# 2                   26            0            3              1
# 3                   21            0            3              1
# 4                   30            0            3              1
# ...                ...          ...          ...            ...
# 45588               32            0            3              1
# 45589               36            0            3              1
# 45590               16            0            3              1
# 45591               26            0            3              1
# 45592               36            0            3              1
#
# [45593 rows x 14 columns]

# %%
age_bins = [0, 30, 50, float('inf')]
age_labels = ['young', 'middle-aged', 'senior']
df['age_category'] = pd.cut(df['Delivery_person_Age'], bins=age_bins, labels=age_labels)

# %%
df['avg_ratings'] = df.groupby('Delivery_person_ID')['Delivery_person_Ratings'].transform('mean')

# %%
df = pd.get_dummies(df, columns=['Type_of_order', 'Type_of_vehicle'])

# %%
df['time_ratings_interaction'] = df['Time_taken(min)'] * df['Delivery_person_Ratings']

# %%
df
# Out:
#          ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0      4607     INDORES13DEL02                   37                      4.9
# 1      B379     BANGRES18DEL02                   34                      4.5
# 2      5D6D     BANGRES19DEL01                   23                      4.4
# 3      7A6A    COIMBRES13DEL02                   38                      4.7
# 4      70A2     CHENRES12DEL01                   32                      4.6
# ...     ...                ...                  ...                      ...
# 45588  7C09      JAPRES04DEL01                   30                      4.8
# 45589  D641      AGRRES16DEL01                   21                      4.6
# 45590  4F8D     CHENRES08DEL03                   30                      4.9
# 45591  5EEE    COIMBRES11DEL01                   20                      4.7
# 45592  5FB2   RANCHIRES09DEL02                   23                      4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0                22.745049             75.892471                   22.765049
# 1                12.913041             77.683237                   13.043041
# 2                12.914264             77.678400                   12.924264
# 3                11.003669             76.976494                   11.053669
# 4                12.972793             80.249982                   13.012793
# ...                    ...                   ...                         ...
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
#        Delivery_location_longitude  Time_taken(min)  hour_of_day  ...  \
# 0                        75.912471               24            0  ...
# 1                        77.813237               33            0  ...
# 2                        77.688400               26            0  ...
# 3                        77.026494               21            0  ...
# 4                        80.289982               30            0  ...
# ...                            ...              ...          ...  ...
# 45588                    75.804257               32            0  ...
# 45589                     0.070000               36            0  ...
# 45590                    80.272439               16            0  ...
# 45591                    77.026241               26            0  ...
# 45592                    85.405731               36            0  ...
#
#        avg_ratings  Type_of_order_Buffet  Type_of_order_Drinks   \
# 0         4.604839                      0                     0
# 1         4.653571                      0                     0
# 2         4.698182                      0                     1
# 3         4.593443                      1                     0
# 4         4.675439                      0                     0
# ...            ...                    ...                   ...
# 45588     4.668333                      0                     0
# 45589     4.592308                      1                     0
# 45590     4.670455                      0                     1
# 45591     4.612903                      0                     0
# 45592     4.639344                      0                     0
#
#        Type_of_order_Meal   Type_of_order_Snack   Type_of_vehicle_bicycle   \
# 0                        0                     1                         0
# 1                        0                     1                         0
# 2                        0                     0                         0
# 3                        0                     0                         0
# 4                        0                     1                         0
# ...                    ...                   ...                       ...
# 45588                    1                     0                         0
# 45589                    0                     0                         0
# 45590                    0                     0                         0
# 45591                    0                     1                         0
# 45592                    0                     1                         0
#
#        Type_of_vehicle_electric_scooter   Type_of_vehicle_motorcycle   \
# 0                                      0                            1
# 1                                      0                            0
# 2                                      0                            1
# 3                                      0                            1
# 4                                      0                            0
# ...                                  ...                          ...
# 45588                                  0                            1
# 45589                                  0                            1
# 45590                                  0                            0
# 45591                                  0                            1
# 45592                                  0                            0
#
#        Type_of_vehicle_scooter   time_ratings_interaction
# 0                             0                     117.6
# 1                             1                     148.5
# 2                             0                     114.4
# 3                             0                      98.7
# 4                             1                     138.0
# ...                         ...                       ...
# 45588                         0                     153.6
# 45589                         0                     165.6
# 45590                         1                      78.4
# 45591                         0                     122.2
# 45592                         1                     176.4
#
# [45593 rows x 23 columns]

# %%
df = df.drop(columns=["ID", "Delivery_person_ID", "Restaurant_latitude", "Restaurant_longitude", "Delivery_location_latitude", "Delivery_location_longitude"])

# %%
df
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Time_taken(min)  \
# 0                       37                      4.9               24
# 1                       34                      4.5               33
# 2                       23                      4.4               26
# 3                       38                      4.7               21
# 4                       32                      4.6               30
# ...                    ...                      ...              ...
# 45588                   30                      4.8               32
# 45589                   21                      4.6               36
# 45590                   30                      4.9               16
# 45591                   20                      4.7               26
# 45592                   23                      4.9               36
#
#        hour_of_day  day_of_week  month_of_year age_category  avg_ratings  \
# 0                0            3              1  middle-aged     4.604839
# 1                0            3              1  middle-aged     4.653571
# 2                0            3              1        young     4.698182
# 3                0            3              1  middle-aged     4.593443
# 4                0            3              1  middle-aged     4.675439
# ...            ...          ...            ...          ...          ...
# 45588            0            3              1        young     4.668333
# 45589            0            3              1        young     4.592308
# 45590            0            3              1        young     4.670455
# 45591            0            3              1        young     4.612903
# 45592            0            3              1        young     4.639344
#
#        Type_of_order_Buffet   Type_of_order_Drinks   Type_of_order_Meal   \
# 0                          0                      0                    0
# 1                          0                      0                    0
# 2                          0                      1                    0
# 3                          1                      0                    0
# 4                          0                      0                    0
# ...                      ...                    ...                  ...
# 45588                      0                      0                    1
# 45589                      1                      0                    0
# 45590                      0                      1                    0
# 45591                      0                      0                    0
# 45592                      0                      0                    0
#
#        Type_of_order_Snack   Type_of_vehicle_bicycle   \
# 0                         1                         0
# 1                         1                         0
# 2                         0                         0
# 3                         0                         0
# 4                         1                         0
# ...                     ...                       ...
# 45588                     0                         0
# 45589                     0                         0
# 45590                     0                         0
# 45591                     1                         0
# 45592                     1                         0
#
#        Type_of_vehicle_electric_scooter   Type_of_vehicle_motorcycle   \
# 0                                      0                            1
# 1                                      0                            0
# 2                                      0                            1
# 3                                      0                            1
# 4                                      0                            0
# ...                                  ...                          ...
# 45588                                  0                            1
# 45589                                  0                            1
# 45590                                  0                            0
# 45591                                  0                            1
# 45592                                  0                            0
#
#        Type_of_vehicle_scooter   time_ratings_interaction
# 0                             0                     117.6
# 1                             1                     148.5
# 2                             0                     114.4
# 3                             0                      98.7
# 4                             1                     138.0
# ...                         ...                       ...
# 45588                         0                     153.6
# 45589                         0                     165.6
# 45590                         1                      78.4
# 45591                         0                     122.2
# 45592                         1                     176.4
#
# [45593 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Delivery_person_Age                45593 non-null  int64
#  1   Delivery_person_Ratings            45593 non-null  float64
#  2   Time_taken(min)                    45593 non-null  int64
#  3   hour_of_day                        45593 non-null  int64
#  4   day_of_week                        45593 non-null  int64
#  5   month_of_year                      45593 non-null  int64
#  6   age_category                       45593 non-null  category
#  7   avg_ratings                        45593 non-null  float64
#  8   Type_of_order_Buffet               45593 non-null  uint8
#  9   Type_of_order_Drinks               45593 non-null  uint8
#  10  Type_of_order_Meal                 45593 non-null  uint8
#  11  Type_of_order_Snack                45593 non-null  uint8
#  12  Type_of_vehicle_bicycle            45593 non-null  uint8
#  13  Type_of_vehicle_electric_scooter   45593 non-null  uint8
#  14  Type_of_vehicle_motorcycle         45593 non-null  uint8
#  15  Type_of_vehicle_scooter            45593 non-null  uint8
#  16  time_ratings_interaction           45593 non-null  float64
# dtypes: category(1), float64(3), int64(5), uint8(8)
# memory usage: 3.2 MB

# %%
df.columns
# Out:
# Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Time_taken(min)',
#        'hour_of_day', 'day_of_week', 'month_of_year', 'age_category',
#        'avg_ratings', 'Type_of_order_Buffet ', 'Type_of_order_Drinks ',
#        'Type_of_order_Meal ', 'Type_of_order_Snack ',
#        'Type_of_vehicle_bicycle ', 'Type_of_vehicle_electric_scooter ',
#        'Type_of_vehicle_motorcycle ', 'Type_of_vehicle_scooter ',
#        'time_ratings_interaction'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error,r2_score,accuracy_score

# %%
features_to_scale = ['Delivery_person_Age', 'Delivery_person_Ratings', 'time_ratings_interaction']
features_not_to_scale = ['Time_taken(min)', 'hour_of_day', 'day_of_week', 'month_of_year',
                         'age_category', 'avg_ratings', 'Type_of_order_Buffet ', 'Type_of_order_Drinks ',
                         'Type_of_order_Meal ', 'Type_of_order_Snack ', 'Type_of_vehicle_bicycle ',
                         'Type_of_vehicle_electric_scooter ', 'Type_of_vehicle_motorcycle ',
                         'Type_of_vehicle_scooter ']
target = 'Time_taken(min)'

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features_to_scale + features_not_to_scale], df[target], test_size=0.25, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = X_train.copy()
X_test_scaled = X_test.copy()
X_train_scaled[features_to_scale] = scaler.fit_transform(X_train_scaled[features_to_scale])
X_test_scaled[features_to_scale] = scaler.transform(X_test_scaled[features_to_scale])

# %%
model = LinearRegression()

# %%
X_train
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  time_ratings_interaction  \
# 21366                   27                      4.9                      83.3
# 45120                   28                      4.9                     137.2
# 24041                   20                      4.9                      68.6
# 11260                   39                      4.8                      72.0
# 5780                    32                      4.8                      96.0
# ...                    ...                      ...                       ...
# 11284                   37                      4.9                     122.5
# 44732                   34                      4.9                      93.1
# 38158                   39                      4.9                     186.2
# 860                     25                      4.9                     142.1
# 15795                   31                      4.6                     138.0
#
#        Time_taken(min)  hour_of_day  day_of_week  month_of_year age_category  \
# 21366               17            0            3              1        young
# 45120               28            0            3              1        young
# 24041               14            0            3              1        young
# 11260               15            0            3              1  middle-aged
# 5780                20            0            3              1  middle-aged
# ...                ...          ...          ...            ...          ...
# 11284               25            0            3              1  middle-aged
# 44732               19            0            3              1  middle-aged
# 38158               38            0            3              1  middle-aged
# 860                 29            0            3              1        young
# 15795               30            0            3              1  middle-aged
#
#        avg_ratings  Type_of_order_Buffet   Type_of_order_Drinks   \
# 21366     4.625424                      0                      0
# 45120     4.774510                      0                      0
# 24041     4.653571                      1                      0
# 11260     4.613115                      0                      0
# 5780      4.596552                      0                      0
# ...            ...                    ...                    ...
# 11284     4.615254                      0                      0
# 44732     4.598148                      0                      0
# 38158     4.683607                      0                      0
# 860       4.609836                      0                      0
# 15795     4.609524                      1                      0
#
#        Type_of_order_Meal   Type_of_order_Snack   Type_of_vehicle_bicycle   \
# 21366                    1                     0                         0
# 45120                    1                     0                         0
# 24041                    0                     0                         0
# 11260                    0                     1                         0
# 5780                     1                     0                         0
# ...                    ...                   ...                       ...
# 11284                    1                     0                         0
# 44732                    0                     1                         0
# 38158                    1                     0                         0
# 860                      1                     0                         0
# 15795                    0                     0                         0
#
#        Type_of_vehicle_electric_scooter   Type_of_vehicle_motorcycle   \
# 21366                                  0                            1
# 45120                                  0                            1
# 24041                                  0                            1
# 11260                                  0                            0
# 5780                                   0                            1
# ...                                  ...                          ...
# 11284                                  0                            0
# 44732                                  0                            1
# 38158                                  0                            1
# 860                                    0                            0
# 15795                                  0                            1
#
#        Type_of_vehicle_scooter
# 21366                         0
# 45120                         0
# 24041                         0
# 11260                         1
# 5780                          0
# ...                         ...
# 11284                         1
# 44732                         0
# 38158                         0
# 860                           1
# 15795                         0
#
# [34194 rows x 17 columns]

# %%
X_train_scaled
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  time_ratings_interaction  \
# 21366            -0.448952                 0.813886                 -0.905445
# 45120            -0.273553                 0.813886                  0.395682
# 24041            -1.676746                 0.813886                 -1.260298
# 11260             1.655838                 0.509080                 -1.178224
# 5780              0.428044                 0.509080                 -0.598872
# ...                    ...                      ...                       ...
# 11284             1.305040                 0.813886                  0.040829
# 44732             0.778842                 0.813886                 -0.668877
# 38158             1.655838                 0.813886                  1.578525
# 860              -0.799750                 0.813886                  0.513966
# 15795             0.252645                -0.100532                  0.414994
#
#        Time_taken(min)  hour_of_day  day_of_week  month_of_year age_category  \
# 21366               17            0            3              1        young
# 45120               28            0            3              1        young
# 24041               14            0            3              1        young
# 11260               15            0            3              1  middle-aged
# 5780                20            0            3              1  middle-aged
# ...                ...          ...          ...            ...          ...
# 11284               25            0            3              1  middle-aged
# 44732               19            0            3              1  middle-aged
# 38158               38            0            3              1  middle-aged
# 860                 29            0            3              1        young
# 15795               30            0            3              1  middle-aged
#
#        avg_ratings  Type_of_order_Buffet   Type_of_order_Drinks   \
# 21366     4.625424                      0                      0
# 45120     4.774510                      0                      0
# 24041     4.653571                      1                      0
# 11260     4.613115                      0                      0
# 5780      4.596552                      0                      0
# ...            ...                    ...                    ...
# 11284     4.615254                      0                      0
# 44732     4.598148                      0                      0
# 38158     4.683607                      0                      0
# 860       4.609836                      0                      0
# 15795     4.609524                      1                      0
#
#        Type_of_order_Meal   Type_of_order_Snack   Type_of_vehicle_bicycle   \
# 21366                    1                     0                         0
# 45120                    1                     0                         0
# 24041                    0                     0                         0
# 11260                    0                     1                         0
# 5780                     1                     0                         0
# ...                    ...                   ...                       ...
# 11284                    1                     0                         0
# 44732                    0                     1                         0
# 38158                    1                     0                         0
# 860                      1                     0                         0
# 15795                    0                     0                         0
#
#        Type_of_vehicle_electric_scooter   Type_of_vehicle_motorcycle   \
# 21366                                  0                            1
# 45120                                  0                            1
# 24041                                  0                            1
# 11260                                  0                            0
# 5780                                   0                            1
# ...                                  ...                          ...
# 11284                                  0                            0
# 44732                                  0                            1
# 38158                                  0                            1
# 860                                    0                            0
# 15795                                  0                            1
#
#        Type_of_vehicle_scooter
# 21366                         0
# 45120                         0
# 24041                         0
# 11260                         1
# 5780                          0
# ...                         ...
# 11284                         1
# 44732                         0
# 38158                         0
# 860                           1
# 15795                         0
#
# [34194 rows x 17 columns]

# %%
ct = ColumnTransformer(
    [('one_hot_encoder', OneHotEncoder(), ['age_category'])],
    remainder='passthrough'
)
X_train_scaled = ct.fit_transform(X_train_scaled)
X_test_scaled = ct.transform(X_test_scaled)

# %%
model.fit(X_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test_scaled)

# %%
y_pred
# Out:
# array([44., 41., 39., ..., 24., 41., 20.])

# %%
rmse = mean_squared_error(y_test, y_pred, squared=False)
print('Root Mean Squared Error:', rmse)
r2_lr = r2_score(y_test, y_pred)
print('R-squared Score:', r2_lr)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Root Mean Squared Error: 2.6356138584357373e-15
# R-squared Score: 1.0
# Mean Squared Error: 6.946460410778514e-30

# %%
dt_regressor = DecisionTreeRegressor(random_state=42)
dt_regressor.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
y_pred_dt = dt_regressor.predict(X_test_scaled)

# %%
y_pred_dt
# Out:
# array([44., 41., 39., ..., 24., 41., 20.])

# %%
rmse_dt = mean_squared_error(y_test, y_pred_dt,squared=False)
print('Decision Tree Regressor - Root Mean Squared Error:', rmse_dt)
r2_dt = r2_score(y_test, y_pred_dt)
print('Decision Tree Regressor - R-squared Score:', r2_dt)
mse_dt = mean_squared_error(y_test, y_pred_dt)
print('Decision Tree Regressor - Mean Squared Error:', mse_dt)
# Out:
# Decision Tree Regressor - Root Mean Squared Error: 0.0
# Decision Tree Regressor - R-squared Score: 1.0
# Decision Tree Regressor - Mean Squared Error: 0.0
